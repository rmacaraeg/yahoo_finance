# %%
from yahooquery import Ticker
import pandas as pd

# %%
aapl = Ticker('aapl')
googl = Ticker('googl')
tickers = [aapl, googl]

# %%
aapl.balance_sheet()
# Out:
#             maxAge     endDate         cash  shortTermInvestments  \
# symbol row
# aapl   0         1  2019-09-28  48844000000           51713000000
#        1         1  2018-09-29  25913000000           40388000000
#        2         1  2017-09-30  20289000000           53892000000
#        3         1  2016-09-24  20484000000           46671000000
#
#             netReceivables   inventory  otherCurrentAssets  \
# symbol row
# aapl   0       45804000000  4106000000         12352000000
#        1       48995000000  3956000000         12087000000
#        2       35673000000  4855000000         13936000000
#        3       29299000000  2132000000          8283000000
#
#             totalCurrentAssets  longTermInvestments  propertyPlantEquipment  \
# symbol row
# aapl   0          162819000000         105341000000             37378000000
#        1          131339000000         170799000000             41304000000
# ...
